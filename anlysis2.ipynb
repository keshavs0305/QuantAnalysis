# %%
import pandas as pd
import numpy as np

# %%
file_data = pd.read_csv('file_data.csv')
file_data
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
file_data

# %%
file_data.date.apply(lambda x:int(x[:4])).unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
year_wise_groups = file_data.loc[file_data.date.apply(lambda x: x[:4] == '2013')].groupby('Name')

# %%
a = year_wise_groups.get_group(tickers[i])[['date','close']]
b = year_wise_groups.get_group(tickers[j])[['date','close']]
a_b = pd.merge(a,b,on='date',how='inner')
a_b = a_b.drop(['date'],axis=1).diff()
a_b.close_x.corr(a_b.close_y)
# Out:
# 0.21087071370783436

# %%
year_wise_groups = file_data.loc[file_data.date.apply(lambda x: x[:4] == '2013')].groupby('Name')

# %%
list(year_wise_groups.Name.unique().index)
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADS',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AET',
#  'AFL',
#  'AGN',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALXN',
#  'AMAT',
#  'AMD',
#  'AME',
#  'AMG',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANDV',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APC',
#  'APD',
#  'APH',
#  'ARE',
#  'ARNC',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AYI',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBT',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BF.B',
#  'BIIB',
#  'BK',
#  'BLK',
#  'BLL',
#  'BMY',
#  'BRK.B',
#  'BSX',
#  'BWA',
#  'BXP',
#  'C',
#  'CA',
#  'CAG',
#  'CAH',
#  'CAT',
#  'CB',
#  'CBG',
#  'CBOE',
#  'CBS',
#  'CCI',
#  'CCL',
#  'CDNS',
#  'CELG',
#  'CERN',
#  'CF',
#  'CHD',
#  'CHK',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
def find_r2(df):
    scaled = StandardScaler().fit_transform(df)
    model = LinearRegression()
    model.fit(scaled[:,0].reshape(-1, 1),scaled[:,1].reshape(-1, 1))
    return model.score(scaled[:,0].reshape(-1, 1),scaled[:,1].reshape(-1, 1))

# %%
ret = {'stock1': [], 'stock2': [], 'r2_score': []}
tickers = list(year_wise_groups.Name.unique().index)
for i in range(len(tickers)-1):
    g1 = year_wise_groups.get_group(tickers[i])[['date','close']]
    for j in range(i+1,len(tickers)):
        g2 = year_wise_groups.get_group(tickers[j])[['date','close']]
        a_b = pd.merge(g1,g2,on='date',how='inner')
        a_b = a_b.drop(['date'],axis=1).diff()
        ret['stock1'].append(tickers[i])
        ret['stock2'].append(tickers[j])
        ret['r2_score'].append(find_r2(a_b.drop([0])))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-5857ee18ddad> in <module>
#       5     for j in range(i+1,len(tickers)):
#       6         g2 = year_wise_groups.get_group(tickers[j])[['date','close']]
# ----> 7         a_b = pd.merge(g1,g2,on='date',how='inner')
#       8         a_b = a_b.drop(['date'],axis=1).diff()
#       9         ret['stock1'].append(tickers[i])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ...

# %%
ret.keys()
# Out:
# dict_keys(['stock1', 'stock2', 'corr'])

# %%
from sklearn.linear_model import LinearRegression

# %%
pd.DataFrame(ret)
# Out:
#     stock1 stock2      corr
# 0        A    AAL  0.026639
# 1        A    AAP  0.081926
# 2        A   AAPL  0.004001
# 3        A   ABBV  0.073651
# 4        A    ABC  0.091395
# ..     ...    ...       ...
# 588    AAL    COL  0.040935
# 589    AAL    COO  0.023144
# 590    AAL    COP  0.018235
# 591    AAL   COST  0.014666
# 592    AAL   COTY  0.001350
#
# [593 rows x 3 columns]
